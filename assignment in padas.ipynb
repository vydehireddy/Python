# %%
import pandas as pd

# %%
# create percentage based on Math, reading and writing score
# based on percentage take out all males scored more than 50%
# based on percentage take out all males scored less than 50%
# same as above for females
#how many females are there 
#how many males are there
# from this data find out how many students parent level of educations are batchelors degree

# %%
# how many males in standard lunch
# how many males in free lunch
# how many females in standard lunch
# how many females in free lunch

# %%
student_data=pd.read_csv(r"C:\Users\vydeh\Downloads\StudentsPerformance.csv")

# %%
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_data["percentage"]=(student_data["math score"]+student_data["reading score"]+student_data["writing score"])/3

# %%
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
1# calculate Males score more than 50%

# %%
student_data.loc[(student_data["percentage"]>50)&(student_data["gender"]=="male")]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4     male        group C                some college      standard
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 4                      none          76             78             75
# ...

# %%
2# calculate Males score less than 50%

# %%
student_data.loc[(student_data["percentage"]<50)&(student_data["gender"]=="male")]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 11    male        group D          associate's degree      standard
# 18    male        group C             master's degree  free/reduced
# 33    male        group D                some college      standard
# ..     ...            ...                         ...           ...
# 889   male        group D                 high school  free/reduced
# 896   male        group B                 high school  free/reduced
# 910   male        group D           bachelor's degree  free/reduced
# 928   male        group E          associate's degree  free/reduced
# 978   male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %%
3# calculate females score more than 50%

# %%
student_data.loc[(student_data["percentage"]>50)&(student_data["gender"]=="female")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
4# calculate females score less than 50%

# %%
student_data.loc[(student_data["percentage"]<50)&(student_data["gender"]=="female")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 55   female        group C                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 80   female        group B          associate's degree      standard
# 145  female        group C                some college  free/reduced
# 174  female        group C           bachelor's degree  free/reduced
# 182  female        group E                 high school      standard
# 217  female        group C                 high school  free/reduced
# 262  female        group C            some high school  free/reduced
# 284  female        group B            some high school      standard
# 323  female        group C            some high school  free/reduced
# ...

# %%
5#calculate Total number of Female Candidates

# %%
fc=student_data.loc[student_data["gender"]=="female"]

# %%
fc
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
6#calculate Total number of male Candidates

# %%
mc=student_data.loc[student_data["gender"]=="male"]

# %%
mc
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %%
7#Total students with parent level education of bachelors degree

# %%
pe=student_data.loc[student_data["parental level of education"]=="bachelor's degree"]

# %%
pe
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
8#how many males in standard lunch

# %%
msl=student_data.loc[(student_data["lunch"]=="standard")&(student_data["gender"]=="male")]

# %%
msl
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 4     male        group C                some college  standard
# 10    male        group C          associate's degree  standard
# 11    male        group D          associate's degree  standard
# 13    male        group A                some college  standard
# 16    male        group C                 high school  standard
# ..     ...            ...                         ...       ...
# 981   male        group D            some high school  standard
# 982   male        group B            some high school  standard
# 985   male        group A                 high school  standard
# 987   male        group E            some high school  standard
# 994   male        group A                 high school  standard
#
#     test preparation course  math score  reading score  writing score  \
# 4                      none          76             78             75
# ...

# %%
9#how many females in standard lunch

# %%
fsl=student_data.loc[(student_data["lunch"]=="standard")&(student_data["gender"]=="female")]

# %%
fsl
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# ..      ...            ...                         ...       ...
# 984  female        group C            some high school  standard
# 986  female        group C          associate's degree  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
10#how many males in free/reduced lunch

# %%
msl=student_data.loc[(student_data["lunch"]=="free/reduced")&(student_data["gender"]=="male")]

# %%
msl
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
# ..     ...            ...                         ...           ...
# 943   male        group A            some high school  free/reduced
# 948   male        group B            some high school  free/reduced
# 976   male        group B                some college  free/reduced
# 990   male        group E                 high school  free/reduced
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %%
11#how many females in free/reduced lunch

# %%
fsl=student_data.loc[(student_data["lunch"]=="free/reduced")&(student_data["gender"]=="female")]

# %%
fsl
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 32   female        group E             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 989  female        group D                some college  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
